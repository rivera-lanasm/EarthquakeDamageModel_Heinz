# %%
import pandas as pd

# %%
output = pd.read_csv("Data/final_output.csv")

# %%
output
# Out:
#            GEOID  max_intensity  population  Total_Num_Building  \
# 0     6055200501           0.54        5159              1364.0
# 1     6095251802           0.34        3132               721.0
# 2     6055200504           0.50        6577              1483.0
# 3     6055201004           0.32        6836              1615.0
# 4     6055200301           0.50        5602              1433.0
# ...          ...            ...         ...                 ...
# 2249  6075980501           0.02         125                16.0
# 2250  6075980200           0.02          79                37.0
# 2251  6041122000           0.02        3669               197.0
# 2252  6109985202           0.01        2734                76.0
# 2253  6075980401           0.01           0                 0.0
#
#       BHI_factor_low  shelter_seeking_low  Total_Num_Building_Slight  \
# 0             0.0587             90.91143                 605.408212
# ...

# %%
output[output["SVI_Value"] != -999]["shelter_seeking_low"].hist()
# Out:
# <Axes: >

# %%
# num buildings damaged (slight, mod, etc.)

# bhi factor low and high

#
